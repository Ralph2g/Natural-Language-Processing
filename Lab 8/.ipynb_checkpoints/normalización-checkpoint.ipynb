# %%
import nltk
from nltk.text import Text
from bs4 import BeautifulSoup
from nltk.corpus import PlaintextCorpusReader
from nltk.corpus import stopwords
from nltk.tokenize import WhitespaceTokenizer
from prettytable import PrettyTable
import re
import pickle
import math
import numpy as np
import os

# %%
#Convertimos en un Pk los objetos
def serializeObject(obj, fname="lemmas2.pkl"):
    with open(fname, "wb") as f:
        pickle.dump(obj, f, -1)
#desconvertimos los pkl
def deserializeObject(fname="lemmas2.pkl"):
    with open(fname, "rb") as f:
        return pickle.load(f)

# %%
def get_articles(fname):
        
    f=open(fname, encoding='utf-8')
    text_string=f.read()
    f.close()
    list_articles = text_string.split('<h3>')
    return list_articles

# %%
def get_text_string(articles):
    '''Receives an html file with a Spanish text, deletes html tags.
    Returns text as a string.'''
    list_articles = []
    for text_string in articles:
        soup = BeautifulSoup(text_string, 'lxml')
        text_string = soup.get_text()
        list_articles.append(text_string)
    return list_articles

# %%
def tagSentencesSpanishTagger(sentences):
    articles = []
    spanish_tagger = deserializeObject("tagger.pkl")#agarramos nuestro tagger entrenado
    for s in sentences:
        aux = []
        tokens = nltk.word_tokenize(s)#Tokenizamos los articulos
        s_tagged = spanish_tagger.tag(tokens)#Taggeamos los tokens
        s_tagged = [(it[0].lower(), it[1][0].lower()) for it in s_tagged]#Pasamos a minusculas
        for word in (lemmatize(removeStopWords(clearTokens(s_tagged)))):
            aux.append(word[0])
        articles.append(aux)#Agregamos las oraciones taggeadas
        
    return articles

#Sacamos las palabras de las oraciones de todas las sentencias
def getWordsFromSentences(sentences):
    words = []
    for sentence in sentences:
        for word in sentence:
            words.append(word)
    return words

#Limpiamos los tokens
def removeStopWords(wordsWithTag, language='spanish'):
    '''Receives a list of words and returns another list without stop words'''
    return [ word for word in wordsWithTag if word[0] not in stopwords.words(language) ]


def clearTokens(tokensWithTag):
    '''Receives a list of  with tag and returns another list with the same tokens but only with letters'''
    result = []
    for token in tokensWithTag:
        clearToken = ""
        for c in token[0]:
            if re.match(r'[a-záéíóúñüA-ZÁÉÍÓÚÑÜ]', c):
                clearToken += c
        if len(clearToken) > 0:
            result.append((clearToken, token[1]))
    return result

def lemmatize(wordsTagged, fname="lemmas2.pkl"):
    lemmas = deserializeObject(fname)
    wordsLemmatized = []
    for word in wordsTagged:
        if word in lemmas.keys():#Si la palabra la encuentra en el dic
            wordsLemmatized.append((lemmas[word], word[1]))#Guardamos el lemma con su tag y la agregamos a las palabras lematizadas
        else:
            wordsLemmatized.append(word)#Si no la encuentra guarda la palabra en el vocabulario en el diccionario
    return wordsLemmatized

# %%
def one_article(articles):
    full =[]
    for article in articles:
        for word in article:
            full.append(word)
    return full

# %%
def frecuency_vec(articles,vocabulary):
    frecuency = []
    for vocabulary_word in vocabulary:
        count = 0
        for word in articles:
            if word == vocabulary_word:
                count +=1
        frecuency.append(count)
    return np.array(frecuency)

# %%
def background(frecuency,voc):
    words = []
    total = np.sum(frecuency)
    for i,word in enumerate(voc):
        #list =[] #LA lista se crea para guardar palabra y probabilidad 
        #list.append(word)
        words.append(( frecuency[i]/total ))
        #words.append(list)
    #words.sort(key = lambda x: x[1], reverse=True) # ya no se ocupa
    return np.array(words)

# %%
def topic(voc):
    words = []
    m = 1/len(voc)
    for word in voc:
        words.append(m)
    return np.array(words)

# %%
def compute_document_likelihood(background_words,
                                topic_words, counts,
                                prob_background,prob_topic,
                                num_iterations = 500,
                                print_likelihood = False):
    argument_for_logarithm = (background_words * prob_background) + (topic_words * prob_topic)
    logarithms = np.log(argument_for_logarithm)
    for i in range(len(logarithms)):
        product = logarithms[i]*counts[i]
        logarithms[i] = product
    document_likelihood = np.sum(logarithms)
    if print_likelihood == True:
        if num_iterations % 20 == 0:
            print('Document likelihood is %f', document_likelihood)
    return logarithms

# %%
def topic_vec(proba,voc):
    words = []
    a = proba
    a.tolist()
    for i,word in enumerate(voc):
        list =[] #LA lista se crea para guardar palabra y probabilidad 
        list.append(word)
        list.append(a[i])
        words.append(list)
    words.sort(key = lambda x: x[1], reverse=False) # ya no se ocupa
    return np.array(words)

# %%
def e_step(prob_topic, topic_words,
           prob_background, background_words):
    z_0_prob = np.divide( (prob_topic*topic_words),( (prob_topic*topic_words) + (prob_background*background_words) ) )
    return z_0_prob

# %%
def m_step(counts,z_0_probs):
    numerator = counts*z_0_probs
    denominator = np.sum(numerator)
    topic_word_probs = numerator/denominator
    return topic_word_probs

# %%
if __name__=='__main__':
    #Cadena de texto
    #---------------PRIMERA PARTE--------------#
    #fname='text.htm'#Cambiamos por txt despues de procesar htm------2
    #articles = get_articles(fname)
    #articles = get_text_string(articles)
    #articles = tagSentencesSpanishTagger(articles)
    articles = deserializeObject('articles.pkl')
    full = one_article(articles)
    vocabulary = set(full)
    #_---PARTE 2------
    frecuency_brute = frecuency_vec(full,vocabulary)
    background_words = background(frecuency_brute,vocabulary)
    aux=[]
    for article in articles:
        background_words = background(frecuency_brute,vocabulary)
        topic_words = topic( vocabulary )
        prob_topic = .5
        prob_background =.5
        iterations = 500
        counts_vec = frecuency_vec(article, vocabulary)
        
        for i in range(iterations):
            
            z_0_probs = e_step(prob_topic, topic_words, prob_background,background_words)
            topic_words = m_step(counts_vec,z_0_probs)
            compute_document_likelihood(background_words,topic_words, counts_vec, prob_background,prob_topic,num_iterations = i,print_likelihood = True)
        
        topic_vector = topic_vec(topic_words,vocabulary)
        aux.append(topic_vector)
    #Instalar gensim
# Out:
# Document likelihood is %f -22.34741284014499
# Document likelihood is %f -18.372443245878873
# Document likelihood is %f -18.372443245878873
# Document likelihood is %f -18.372443245878873
# Document likelihood is %f -18.372443245878873
# Document likelihood is %f -18.372443245878873
# Document likelihood is %f -18.372443245878873
# Document likelihood is %f -18.372443245878873
# Document likelihood is %f -18.372443245878873
# Document likelihood is %f -18.372443245878873
# Document likelihood is %f -18.372443245878873
# Document likelihood is %f -18.372443245878873
# Document likelihood is %f -18.372443245878873
# Document likelihood is %f -18.372443245878873
# Document likelihood is %f -18.372443245878873
# Document likelihood is %f -18.372443245878873
# Document likelihood is %f -18.372443245878873
# Document likelihood is %f -18.372443245878873
# Document likelihood is %f -18.372443245878873
# Document likelihood is %f -18.372443245878873
# Document likelihood is %f -18.372443245878873
# Document likelihood is %f -18.372443245878873
# Document likelihood is %f -18.372443245878873
# Document likelihood is %f -18.372443245878873
# Document likelihood is %f -18.372443245878873
# Document likelihood is %f -1226.4395593312022
# Document likelihood is %f -1201.1448376097583
# Document likelihood is %f -1201.14404200545
# Document likelihood is %f -1201.1438597289302
# Document likelihood is %f -1201.143796211073
# Document likelihood is %f -1201.1437657673273
# Document likelihood is %f -1201.1437481627768
# Document likelihood is %f -1201.143736956517
# Document likelihood is %f -1201.1437294436719
# Document likelihood is %f -1201.1437242455213
# Document likelihood is %f -1201.14372057236
# Document likelihood is %f -1201.1437179381246
# Document likelihood is %f -1201.1437160287364
# Document likelihood is %f -1201.1437146339515
# Document likelihood is %f -1201.1437136092475
# Document likelihood is %f -1201.143712853253
# Document likelihood is %f -1201.1437122937616
# Document likelihood is %f -1201.143711878738
# Document likelihood is %f -1201.1437115703488
# Document likelihood is %f -1201.1437113409024
# Document likelihood is %f -1201.143711170028
# Document likelihood is %f -1201.1437110426828
# Document likelihood is %f -1201.1437109477279
# Document likelihood is %f -1201.1437108768966
# Document likelihood is %f -1201.1437108240448
# Document likelihood is %f -1684.9680385852066
# Document likelihood is %f -1655.1967739222064
# Document likelihood is %f -1655.1966500120134
# Document likelihood is %f -1655.196643288177
# Document likelihood is %f -1655.1966424154703
# Document likelihood is %f -1655.196642288475
# Document likelihood is %f -1655.196642269489
# Document likelihood is %f -1655.1966422666228
# Document likelihood is %f -1655.1966422661885
# Document likelihood is %f -1655.1966422661226
# Document likelihood is %f -1655.1966422661126
# Document likelihood is %f -1655.1966422661112
# Document likelihood is %f -1655.1966422661108
# Document likelihood is %f -1655.1966422661108
# Document likelihood is %f -1655.1966422661108
# Document likelihood is %f -1655.1966422661108
# Document likelihood is %f -1655.196642266111
# Document likelihood is %f -1655.1966422661108
# Document likelihood is %f -1655.196642266111
# Document likelihood is %f -1655.1966422661108
# Document likelihood is %f -1655.1966422661108
# Document likelihood is %f -1655.1966422661108
# Document likelihood is %f -1655.1966422661108
# Document likelihood is %f -1655.1966422661108
# Document likelihood is %f -1655.1966422661108
# Document likelihood is %f -1525.29589055624
# Document likelihood is %f -1497.132183762788
# Document likelihood is %f -1497.1315818341468
# Document likelihood is %f -1497.1315638976996
# Document likelihood is %f -1497.1315632844146
# Document likelihood is %f -1497.1315632629357
# Document likelihood is %f -1497.1315632621795
# Document likelihood is %f -1497.1315632621531
# Document likelihood is %f -1497.131563262152
# Document likelihood is %f -1497.131563262152
# Document likelihood is %f -1497.1315632621518
# Document likelihood is %f -1497.1315632621518
# Document likelihood is %f -1497.131563262152
# Document likelihood is %f -1497.131563262152
# Document likelihood is %f -1497.131563262152
# Document likelihood is %f -1497.131563262152
# Document likelihood is %f -1497.131563262152
# Document likelihood is %f -1497.131563262152
# Document likelihood is %f -1497.131563262152
# Document likelihood is %f -1497.131563262152
# Document likelihood is %f -1497.131563262152
# Document likelihood is %f -1497.131563262152
# Document likelihood is %f -1497.131563262152
# Document likelihood is %f -1497.131563262152
# Document likelihood is %f -1497.131563262152
# Document likelihood is %f -1221.4788615602774
# Document likelihood is %f -1185.3240108444068
# Document likelihood is %f -1185.3237535255603
# Document likelihood is %f -1185.3237201469917
# Document likelihood is %f -1185.3237105921548
# Document likelihood is %f -1185.3237073228147
# Document likelihood is %f -1185.3237061080208
# Document likelihood is %f -1185.3237056344574
# Document likelihood is %f -1185.3237054443537
# Document likelihood is %f -1185.323705366627
# Document likelihood is %f -1185.323705334475
# Document likelihood is %f -1185.3237053210762
# Document likelihood is %f -1185.3237053154655
# Document likelihood is %f -1185.3237053131086
# Document likelihood is %f -1185.3237053121165
# Document likelihood is %f -1185.3237053116986
# Document likelihood is %f -1185.3237053115224
# Document likelihood is %f -1185.3237053114478
# Document likelihood is %f -1185.3237053114165
# Document likelihood is %f -1185.3237053114033
# Document likelihood is %f -1185.3237053113976
# Document likelihood is %f -1185.3237053113953
# Document likelihood is %f -1185.3237053113944
# Document likelihood is %f -1185.323705311394
# Document likelihood is %f -1185.3237053113937
# Document likelihood is %f -1360.9643763960926
# Document likelihood is %f -1338.5530404977517
# Document likelihood is %f -1338.5525242552324
# Document likelihood is %f -1338.5524325601116
# Document likelihood is %f -1338.5524144493606
# Document likelihood is %f -1338.552410800573
# Document likelihood is %f -1338.5524100625157
# Document likelihood is %f -1338.5524099131053
# Document likelihood is %f -1338.5524098828541
# Document likelihood is %f -1338.552409876729
# Document likelihood is %f -1338.5524098754888
# Document likelihood is %f -1338.5524098752376
# Document likelihood is %f -1338.5524098751866
# Document likelihood is %f -1338.5524098751762
# Document likelihood is %f -1338.5524098751744
# Document likelihood is %f -1338.552409875174
# Document likelihood is %f -1338.552409875174
# Document likelihood is %f -1338.552409875174
# Document likelihood is %f -1338.5524098751737
# Document likelihood is %f -1338.5524098751737
# Document likelihood is %f -1338.5524098751737
# Document likelihood is %f -1338.5524098751737
# Document likelihood is %f -1338.5524098751737
# Document likelihood is %f -1338.5524098751737
# Document likelihood is %f -1338.5524098751737
# Document likelihood is %f -1845.5701101591449
# Document likelihood is %f -1797.720233899924
# Document likelihood is %f -1797.7197635362133
# Document likelihood is %f -1797.719673316011
# Document likelihood is %f -1797.71964581947
# Document likelihood is %f -1797.7196356275285
# Document likelihood is %f -1797.719631360137
# Document likelihood is %f -1797.7196294165503
# Document likelihood is %f -1797.719628475835
# Document likelihood is %f -1797.7196279997597
# Document likelihood is %f -1797.719627750837
# Document likelihood is %f -1797.7196276175598
# Document likelihood is %f -1797.719627544969
# Document likelihood is %f -1797.719627504941
# Document likelihood is %f -1797.7196274826724
# Document likelihood is %f -1797.7196274702046
# Document likelihood is %f -1797.719627463192
# Document likelihood is %f -1797.7196274592347
# Document likelihood is %f -1797.7196274569956
# Document likelihood is %f -1797.7196274557268
# Document likelihood is %f -1797.719627455007
# Document likelihood is %f -1797.7196274545977
# Document likelihood is %f -1797.7196274543653
# Document likelihood is %f -1797.7196274542332
# Document likelihood is %f -1797.719627454158
# Document likelihood is %f -1635.2199882584305
# Document likelihood is %f -1597.4912403723677
# Document likelihood is %f -1597.49093793582
# Document likelihood is %f -1597.4909328956728
# Document likelihood is %f -1597.490932715701
# Document likelihood is %f -1597.4909327042265
# Document likelihood is %f -1597.4909327033624
# Document likelihood is %f -1597.4909327032951
# Document likelihood is %f -1597.4909327032897
# Document likelihood is %f -1597.4909327032897
# Document likelihood is %f -1597.4909327032897
# Document likelihood is %f -1597.4909327032894
# Document likelihood is %f -1597.4909327032897
# Document likelihood is %f -1597.4909327032894
# Document likelihood is %f -1597.4909327032892
# Document likelihood is %f -1597.4909327032894
# Document likelihood is %f -1597.4909327032894
# Document likelihood is %f -1597.4909327032894
# Document likelihood is %f -1597.4909327032894
# Document likelihood is %f -1597.4909327032892
# Document likelihood is %f -1597.4909327032897
# Document likelihood is %f -1597.4909327032894
# Document likelihood is %f -1597.4909327032894
# Document likelihood is %f -1597.4909327032894
# Document likelihood is %f -1597.4909327032894
# Document likelihood is %f -605.9655542025694
# Document likelihood is %f -584.62480270382
# Document likelihood is %f -584.6248024578854
# Document likelihood is %f -584.6248024578854
# Document likelihood is %f -584.6248024578853
# Document likelihood is %f -584.6248024578854
# Document likelihood is %f -584.6248024578854
# Document likelihood is %f -584.6248024578854
# Document likelihood is %f -584.6248024578854
# Document likelihood is %f -584.6248024578854
# Document likelihood is %f -584.6248024578854
# Document likelihood is %f -584.6248024578854
# Document likelihood is %f -584.6248024578854
# Document likelihood is %f -584.6248024578854
# Document likelihood is %f -584.6248024578854
# Document likelihood is %f -584.6248024578854
# Document likelihood is %f -584.6248024578854
# Document likelihood is %f -584.6248024578854
# Document likelihood is %f -584.6248024578854
# Document likelihood is %f -584.6248024578854
# Document likelihood is %f -584.6248024578854
# Document likelihood is %f -584.6248024578854
# Document likelihood is %f -584.6248024578854
# Document likelihood is %f -584.6248024578854
# Document likelihood is %f -584.6248024578854
# Document likelihood is %f -675.9248797856316
# Document likelihood is %f -655.0794508175818
# Document likelihood is %f -655.0794445749436
# Document likelihood is %f -655.079444574724
# Document likelihood is %f -655.0794445747241
# Document likelihood is %f -655.0794445747241
# Document likelihood is %f -655.0794445747241
# Document likelihood is %f -655.0794445747241
# Document likelihood is %f -655.0794445747241
# Document likelihood is %f -655.0794445747241
# Document likelihood is %f -655.0794445747241
# Document likelihood is %f -655.0794445747241
# Document likelihood is %f -655.0794445747241
# Document likelihood is %f -655.0794445747241
# Document likelihood is %f -655.0794445747241
# Document likelihood is %f -655.0794445747241
# Document likelihood is %f -655.0794445747241
# Document likelihood is %f -655.0794445747241
# Document likelihood is %f -655.0794445747241
# Document likelihood is %f -655.0794445747241
# Document likelihood is %f -655.0794445747241
# Document likelihood is %f -655.0794445747241
# Document likelihood is %f -655.0794445747241
# Document likelihood is %f -655.0794445747241
# Document likelihood is %f -655.0794445747241
# Document likelihood is %f -1950.3147896147152
# Document likelihood is %f -1893.989666374083
# Document likelihood is %f -1893.986740310558
# Document likelihood is %f -1893.9861736748912
# Document likelihood is %f -1893.9860318505796
# Document likelihood is %f -1893.985991556251
# Document likelihood is %f -1893.9859791169326
# Document likelihood is %f -1893.985975057346
# Document likelihood is %f -1893.9859736830704
# Document likelihood is %f -1893.9859732064278
# Document likelihood is %f -1893.9859730383707
# Document likelihood is %f -1893.9859729784255
# Document likelihood is %f -1893.9859729568616
# Document likelihood is %f -1893.9859729490552
# Document likelihood is %f -1893.985972946215
# Document likelihood is %f -1893.985972945178
# Document likelihood is %f -1893.985972944798
# Document likelihood is %f -1893.9859729446587
# Document likelihood is %f -1893.985972944607
# Document likelihood is %f -1893.9859729445884
# Document likelihood is %f -1893.9859729445816
# Document likelihood is %f -1893.9859729445786
# Document likelihood is %f -1893.985972944578
# Document likelihood is %f -1893.9859729445775
# Document likelihood is %f -1893.9859729445773
# Document likelihood is %f -814.1954504343452
# Document likelihood is %f -782.2849810940893
# Document likelihood is %f -782.2849807684584
# Document likelihood is %f -782.2849807684577
# Document likelihood is %f -782.2849807684577
# Document likelihood is %f -782.2849807684574
# Document likelihood is %f -782.2849807684574
# Document likelihood is %f -782.2849807684574
# Document likelihood is %f -782.2849807684574
# Document likelihood is %f -782.2849807684574
# Document likelihood is %f -782.2849807684574
# Document likelihood is %f -782.2849807684574
# Document likelihood is %f -782.2849807684574
# Document likelihood is %f -782.2849807684574
# Document likelihood is %f -782.2849807684574
# Document likelihood is %f -782.2849807684574
# Document likelihood is %f -782.2849807684574
# Document likelihood is %f -782.2849807684574
# Document likelihood is %f -782.2849807684574
# Document likelihood is %f -782.2849807684574
# Document likelihood is %f -782.2849807684574
# Document likelihood is %f -782.2849807684574
# Document likelihood is %f -782.2849807684574
# Document likelihood is %f -782.2849807684574
# Document likelihood is %f -782.2849807684574
# Document likelihood is %f -809.6063732432764
# Document likelihood is %f -777.3356946811352
# Document likelihood is %f -777.3356842507118
# Document likelihood is %f -777.3356842190417
# Document likelihood is %f -777.3356842189507
# Document likelihood is %f -777.3356842189504
# Document likelihood is %f -777.3356842189504
# Document likelihood is %f -777.3356842189504
# Document likelihood is %f -777.3356842189505
# Document likelihood is %f -777.3356842189504
# Document likelihood is %f -777.3356842189504
# Document likelihood is %f -777.3356842189504
# Document likelihood is %f -777.3356842189504
# Document likelihood is %f -777.3356842189504
# Document likelihood is %f -777.3356842189504
# Document likelihood is %f -777.3356842189504
# Document likelihood is %f -777.3356842189504
# Document likelihood is %f -777.3356842189504
# Document likelihood is %f -777.3356842189504
# Document likelihood is %f -777.3356842189504
# Document likelihood is %f -777.3356842189504
# Document likelihood is %f -777.3356842189504
# Document likelihood is %f -777.3356842189504
# Document likelihood is %f -777.3356842189504
# Document likelihood is %f -777.3356842189504
# Document likelihood is %f -823.8660818888723
# Document likelihood is %f -789.5405273188053
# Document likelihood is %f -789.5405272000708
# Document likelihood is %f -789.5405272000708
# Document likelihood is %f -789.5405272000706
# Document likelihood is %f -789.5405272000708
# Document likelihood is %f -789.5405272000708
# Document likelihood is %f -789.5405272000708
# Document likelihood is %f -789.5405272000708
# Document likelihood is %f -789.5405272000708
# Document likelihood is %f -789.5405272000708
# Document likelihood is %f -789.5405272000708
# Document likelihood is %f -789.5405272000708
# Document likelihood is %f -789.5405272000708
# Document likelihood is %f -789.5405272000708
# Document likelihood is %f -789.5405272000708
# Document likelihood is %f -789.5405272000708
# Document likelihood is %f -789.5405272000708
# Document likelihood is %f -789.5405272000708
# Document likelihood is %f -789.5405272000708
# Document likelihood is %f -789.5405272000708
# Document likelihood is %f -789.5405272000708
# Document likelihood is %f -789.5405272000708
# Document likelihood is %f -789.5405272000708
# Document likelihood is %f -789.5405272000708
# Document likelihood is %f -691.9269239319267
# Document likelihood is %f -668.0310622964741
# Document likelihood is %f -668.0310597016066
# Document likelihood is %f -668.0310597015635
# Document likelihood is %f -668.0310597015635
# Document likelihood is %f -668.0310597015635
# Document likelihood is %f -668.0310597015634
# Document likelihood is %f -668.0310597015634
# Document likelihood is %f -668.0310597015634
# Document likelihood is %f -668.0310597015634
# Document likelihood is %f -668.0310597015634
# Document likelihood is %f -668.0310597015634
# Document likelihood is %f -668.0310597015634
# Document likelihood is %f -668.0310597015634
# Document likelihood is %f -668.0310597015634
# Document likelihood is %f -668.0310597015634
# Document likelihood is %f -668.0310597015634
# Document likelihood is %f -668.0310597015634
# Document likelihood is %f -668.0310597015634
# Document likelihood is %f -668.0310597015634
# Document likelihood is %f -668.0310597015634
# Document likelihood is %f -668.0310597015634
# Document likelihood is %f -668.0310597015634
# Document likelihood is %f -668.0310597015634
# Document likelihood is %f -668.0310597015634
# Document likelihood is %f -2350.168414569411
# Document likelihood is %f -2286.2422032546046
# Document likelihood is %f -2286.2406162515736
# Document likelihood is %f -2286.240329285264
# Document likelihood is %f -2286.240224631318
# Document likelihood is %f -2286.2401776558754
# Document likelihood is %f -2286.2401545898656
# Document likelihood is %f -2286.240142719478
# Document likelihood is %f -2286.240136446958
# Document likelihood is %f -2286.240133079951
# Document likelihood is %f -2286.240131254586
# Document likelihood is %f -2286.240130258323
# Document likelihood is %f -2286.240129711875
# Document likelihood is %f -2286.2401294109586
# Document likelihood is %f -2286.2401292446802
# Document likelihood is %f -2286.2401291525102
# Document likelihood is %f -2286.2401291012657
# Document likelihood is %f -2286.2401290726907
# Document likelihood is %f -2286.24012905671
# Document likelihood is %f -2286.2401290477455
# Document likelihood is %f -2286.2401290427024
# Document likelihood is %f -2286.240129039857
# Document likelihood is %f -2286.240129038246
# Document likelihood is %f -2286.240129037332
# Document likelihood is %f -2286.2401290368107
# Document likelihood is %f -8424.708763867067
# Document likelihood is %f -8252.568388293332
# Document likelihood is %f -8252.553864971782
# Document likelihood is %f -8252.552250218681
# Document likelihood is %f -8252.5519106747
# Document likelihood is %f -8252.551811485235
# Document likelihood is %f -8252.551773394243
# Document likelihood is %f -8252.551755083161
# Document likelihood is %f -8252.55174477841
# Document likelihood is %f -8252.551738393418
# Document likelihood is %f -8252.551734215853
# Document likelihood is %f -8252.551731398808
# Document likelihood is %f -8252.551729466546
# Document likelihood is %f -8252.551728127866
# Document likelihood is %f -8252.551727194736
# Document likelihood is %f -8252.551726541755
# Document likelihood is %f -8252.55172608365
# Document likelihood is %f -8252.551725761703
# Document likelihood is %f -8252.551725535184
# Document likelihood is %f -8252.551725375675
# Document likelihood is %f -8252.551725263289
# Document likelihood is %f -8252.551725184074
# Document likelihood is %f -8252.551725128222
# Document likelihood is %f -8252.551725088837
# Document likelihood is %f -8252.55172506106
# Document likelihood is %f -1113.4235103692981
# Document likelihood is %f -1083.7010617269802
# Document likelihood is %f -1083.7010615382462
# Document likelihood is %f -1083.7010615342224
# Document likelihood is %f -1083.7010615341283
# Document likelihood is %f -1083.701061534126
# Document likelihood is %f -1083.701061534126
# Document likelihood is %f -1083.701061534126
# Document likelihood is %f -1083.7010615341258
# Document likelihood is %f -1083.701061534126
# Document likelihood is %f -1083.701061534126
# Document likelihood is %f -1083.7010615341258
# Document likelihood is %f -1083.7010615341258
# Document likelihood is %f -1083.701061534126
# Document likelihood is %f -1083.7010615341258
# Document likelihood is %f -1083.7010615341258
# Document likelihood is %f -1083.7010615341258
# Document likelihood is %f -1083.7010615341258
# Document likelihood is %f -1083.7010615341258
# Document likelihood is %f -1083.7010615341258
# Document likelihood is %f -1083.7010615341258
# Document likelihood is %f -1083.7010615341258
# Document likelihood is %f -1083.7010615341258
# Document likelihood is %f -1083.7010615341258
# Document likelihood is %f -1083.7010615341258
# Document likelihood is %f -1887.4838548988562
# Document likelihood is %f -1853.541973294734
# Document likelihood is %f -1853.541477205292
# Document likelihood is %f -1853.5413392263172
# Document likelihood is %f -1853.5412786532304
# Document likelihood is %f -1853.5412463534321
# Document likelihood is %f -1853.5412270558086
# Document likelihood is %f -1853.5412146551162
# Document likelihood is %f -1853.541206283579
# Document likelihood is %f -1853.5412004330135
# Document likelihood is %f -1853.541196241124
# Document likelihood is %f -1853.541193182345
# Document likelihood is %f -1853.541190919949
# Document likelihood is %f -1853.541189229522
# Document likelihood is %f -1853.5411879567514
# Document likelihood is %f -1853.5411869928632
# Document likelihood is %f -1853.5411862596588
# Document likelihood is %f -1853.5411857000406
# Document likelihood is %f -1853.5411852718044
# Document likelihood is %f -1853.541184943454
# Document likelihood is %f -1853.5411846913062
# Document likelihood is %f -1853.5411844974487
# Document likelihood is %f -1853.5411843482716
# Document likelihood is %f -1853.5411842333972
# Document likelihood is %f -1853.54118414489
# Document likelihood is %f -5465.314524198255
# Document likelihood is %f -5383.390860661415
# Document likelihood is %f -5383.384144794158
# Document likelihood is %f -5383.383338785717
# Document likelihood is %f -5383.38308562527
# Document likelihood is %f -5383.382969431763
# Document likelihood is %f -5383.382907516246
# Document likelihood is %f -5383.3828719612375
# Document likelihood is %f -5383.382850616354
# Document likelihood is %f -5383.382837427561
# Document likelihood is %f -5383.382829113781
# Document likelihood is %f -5383.382823794637
# Document likelihood is %f -5383.382820350778
# Document likelihood is %f -5383.382818098113
# Document likelihood is %f -5383.38281661067
# Document likelihood is %f -5383.382815619516
# Document likelihood is %f -5383.382814953029
# Document likelihood is %f -5383.382814500703
# Document likelihood is %f -5383.382814190811
# Document likelihood is %f -5383.382813976457
# Document likelihood is %f -5383.382813826745
# Document likelihood is %f -5383.382813721168
# Document likelihood is %f -5383.382813646003
# Document likelihood is %f -5383.382813591998
# Document likelihood is %f -5383.382813552853
# Document likelihood is %f -13272.400057475355
# Document likelihood is %f -13131.912213213445
# Document likelihood is %f -13131.891530160345
# Document likelihood is %f -13131.889334127534
# Document likelihood is %f -13131.888761083725
# Document likelihood is %f -13131.888542442677
# Document likelihood is %f -13131.888439534177
# Document likelihood is %f -13131.88838367532
# Document likelihood is %f -13131.888349992441
# Document likelihood is %f -13131.88832800265
# Document likelihood is %f -13131.888312756279
# Document likelihood is %f -13131.888301694897
# Document likelihood is %f -13131.888293392722
# Document likelihood is %f -13131.88828700188
# Document likelihood is %f -13131.888281988622
# Document likelihood is %f -13131.888277999808
# Document likelihood is %f -13131.88827479165
# Document likelihood is %f -13131.888272189786
# Document likelihood is %f -13131.888270065821
# Document likelihood is %f -13131.888268322968
# Document likelihood is %f -13131.888266886872
# Document likelihood is %f -13131.888265699534
# Document likelihood is %f -13131.88826471514
# Document likelihood is %f -13131.888263897139
# Document likelihood is %f -13131.888263216124
# Document likelihood is %f -3089.1144024840733
# Document likelihood is %f -3002.253129856522
# Document likelihood is %f -3002.248786998049
# Document likelihood is %f -3002.248135093235
# Document likelihood is %f -3002.2479495214084
# Document likelihood is %f -3002.2478748935855
# Document likelihood is %f -3002.2478364437975
# Document likelihood is %f -3002.2478133448353
# Document likelihood is %f -3002.2477981601105
# Document likelihood is %f -3002.24778759607
# Document likelihood is %f -3002.2477799497033
# Document likelihood is %f -3002.247774246589
# Document likelihood is %f -3002.247769890172
# Document likelihood is %f -3002.2477664969365
# Document likelihood is %f -3002.2477638107475
# Document likelihood is %f -3002.2477616550987
# Document likelihood is %f -3002.247759905088
# Document likelihood is %f -3002.247758470279
# Document likelihood is %f -3002.247757283869
# Document likelihood is %f -3002.24775629563
# Document likelihood is %f -3002.247755467208
# Document likelihood is %f -3002.2477547688964
# Document likelihood is %f -3002.2477541774033
# Document likelihood is %f -3002.247753674257
# Document likelihood is %f -3002.247753244662
# Document likelihood is %f -2922.3868528954727
# Document likelihood is %f -2862.8304341130215
# Document likelihood is %f -2862.827501381498
# Document likelihood is %f -2862.82724050831
# Document likelihood is %f -2862.8271814327404
# Document likelihood is %f -2862.827163658566
# Document likelihood is %f -2862.8271579769976
# Document likelihood is %f -2862.8271561356514
# Document likelihood is %f -2862.827155536771
# Document likelihood is %f -2862.827155341798
# Document likelihood is %f -2862.8271552783035
# Document likelihood is %f -2862.827155257624
# Document likelihood is %f -2862.8271552508886
# Document likelihood is %f -2862.827155248695
# Document likelihood is %f -2862.827155247981
# Document likelihood is %f -2862.827155247748
# Document likelihood is %f -2862.8271552476717
# Document likelihood is %f -2862.8271552476476
# Document likelihood is %f -2862.82715524764
# Document likelihood is %f -2862.827155247637
# Document likelihood is %f -2862.8271552476363
# Document likelihood is %f -2862.827155247636
# Document likelihood is %f -2862.827155247636
# Document likelihood is %f -2862.8271552476353
# Document likelihood is %f -2862.8271552476353
# Document likelihood is %f -1225.3345618216977
# Document likelihood is %f -1194.147526124547
# Document likelihood is %f -1194.1473510075969
# Document likelihood is %f -1194.147303899008
# Document likelihood is %f -1194.14728651917
# Document likelihood is %f -1194.147278944633
# Document likelihood is %f -1194.1472752914824
# Document likelihood is %f -1194.1472734081617
# Document likelihood is %f -1194.1472723914644
# Document likelihood is %f -1194.1472718242271
# Document likelihood is %f -1194.1472715000305
# Document likelihood is %f -1194.1472713113842
# Document likelihood is %f -1194.1472712001168
# Document likelihood is %f -1194.14727113381
# Document likelihood is %f -1194.1472710939822
# Document likelihood is %f -1194.1472710699134
# Document likelihood is %f -1194.1472710552994
# Document likelihood is %f -1194.1472710463934
# Document likelihood is %f -1194.1472710409505
# Document likelihood is %f -1194.147271037617
# Document likelihood is %f -1194.147271035571
# Document likelihood is %f -1194.1472710343146
# Document likelihood is %f -1194.1472710335415
# Document likelihood is %f -1194.1472710330656
# Document likelihood is %f -1194.1472710327726
# Document likelihood is %f -2477.360539496763
# Document likelihood is %f -2433.6895099614417
# Document likelihood is %f -2433.6872400609855
# Document likelihood is %f -2433.6868380204387
# Document likelihood is %f -2433.686702969705
# Document likelihood is %f -2433.6866460738447
# Document likelihood is %f -2433.6866191942336
# Document likelihood is %f -2433.6866053245794
# Document likelihood is %f -2433.6865975510036
# Document likelihood is %f -2433.686592833894
# Document likelihood is %f -2433.6865897561956
# Document likelihood is %f -2433.686587620072
# Document likelihood is %f -2433.686586061809
# Document likelihood is %f -2433.6865848802445
# Document likelihood is %f -2433.6865839572656
# Document likelihood is %f -2433.68658321947
# Document likelihood is %f -2433.6865826188546
# Document likelihood is %f -2433.686582122635
# Document likelihood is %f -2433.6865817075945
# Document likelihood is %f -2433.6865813568
# Document likelihood is %f -2433.6865810576037
# Document likelihood is %f -2433.6865808003668
# Document likelihood is %f -2433.686580577622
# Document likelihood is %f -2433.686580383501
# Document likelihood is %f -2433.686580213339
# Document likelihood is %f -3147.066226527543
# Document likelihood is %f -3070.1681258914095
# Document likelihood is %f -3070.165811202557
# Document likelihood is %f -3070.165588789914
# Document likelihood is %f -3070.1655200397695
# Document likelihood is %f -3070.165489370129
# Document likelihood is %f -3070.165473243017
# Document likelihood is %f -3070.1654637846505
# Document likelihood is %f -3070.165457769361
# Document likelihood is %f -3070.165453697701
# Document likelihood is %f -3070.165450803791
# Document likelihood is %f -3070.1654486658863
# Document likelihood is %f -3070.1654470368167
# Document likelihood is %f -3070.1654457638974
# Document likelihood is %f -3070.165444748487
# Document likelihood is %f -3070.1654439243703
# Document likelihood is %f -3070.165443245628
# Document likelihood is %f -3070.1654426795108
# Document likelihood is %f -3070.165442202106
# Document likelihood is %f -3070.165441795587
# Document likelihood is %f -3070.1654414464274
# Document likelihood is %f -3070.165441144203
# Document likelihood is %f -3070.165440880771
# Document likelihood is %f -3070.165440649689
# Document likelihood is %f -3070.165440445808
# Document likelihood is %f -1404.5991604506653
# Document likelihood is %f -1358.9986410282054
# Document likelihood is %f -1358.997963108828
# Document likelihood is %f -1358.9978595712591
# Document likelihood is %f -1358.9978418306541
# Document likelihood is %f -1358.9978387324263
# Document likelihood is %f -1358.9978381895558
# Document likelihood is %f -1358.9978380943787
# Document likelihood is %f -1358.9978380776904
# Document likelihood is %f -1358.9978380747643
# Document likelihood is %f -1358.9978380742514
# Document likelihood is %f -1358.9978380741613
# Document likelihood is %f -1358.9978380741454
# Document likelihood is %f -1358.9978380741427
# Document likelihood is %f -1358.9978380741425
# Document likelihood is %f -1358.9978380741422
# Document likelihood is %f -1358.9978380741422
# Document likelihood is %f -1358.9978380741422
# Document likelihood is %f -1358.9978380741422
# Document likelihood is %f -1358.9978380741422
# Document likelihood is %f -1358.9978380741422
# Document likelihood is %f -1358.9978380741422
# Document likelihood is %f -1358.9978380741422
# Document likelihood is %f -1358.9978380741422
# Document likelihood is %f -1358.9978380741422
# Document likelihood is %f -3632.5883209729996
# Document likelihood is %f -3537.693797543093
# Document likelihood is %f -3537.6910712953127
# Document likelihood is %f -3537.6908217612345
# Document likelihood is %f -3537.690777337421
# Document likelihood is %f -3537.690767807683
# Document likelihood is %f -3537.690765657151
# Document likelihood is %f -3537.6907651604865
# Document likelihood is %f -3537.690765043634
# Document likelihood is %f -3537.6907650156336
# Document likelihood is %f -3537.690765008797
# Document likelihood is %f -3537.690765007096
# Document likelihood is %f -3537.690765006665
# Document likelihood is %f -3537.690765006554
# Document likelihood is %f -3537.6907650065245
# Document likelihood is %f -3537.690765006517
# Document likelihood is %f -3537.6907650065145
# Document likelihood is %f -3537.690765006514
# Document likelihood is %f -3537.690765006514
# Document likelihood is %f -3537.690765006514
# Document likelihood is %f -3537.690765006514
# Document likelihood is %f -3537.690765006514
# Document likelihood is %f -3537.6907650065136
# Document likelihood is %f -3537.6907650065136
# Document likelihood is %f -3537.6907650065136
# Document likelihood is %f -1511.6353962786873
# Document likelihood is %f -1456.9592111526918
# Document likelihood is %f -1456.9585895139758
# Document likelihood is %f -1456.9585706046869
# Document likelihood is %f -1456.9585699690128
# Document likelihood is %f -1456.9585699442337
# Document likelihood is %f -1456.95856994306
# Document likelihood is %f -1456.9585699429933
# Document likelihood is %f -1456.958569942989
# Document likelihood is %f -1456.9585699429886
# Document likelihood is %f -1456.9585699429886
# Document likelihood is %f -1456.9585699429888
# Document likelihood is %f -1456.9585699429886
# Document likelihood is %f -1456.9585699429886
# Document likelihood is %f -1456.9585699429886
# Document likelihood is %f -1456.9585699429886
# Document likelihood is %f -1456.9585699429886
# Document likelihood is %f -1456.9585699429888
# Document likelihood is %f -1456.9585699429886
# Document likelihood is %f -1456.9585699429886
# Document likelihood is %f -1456.9585699429888
# Document likelihood is %f -1456.958569942989
# Document likelihood is %f -1456.9585699429886
# Document likelihood is %f -1456.9585699429886
# Document likelihood is %f -1456.9585699429886
# Document likelihood is %f -3340.6608509360576
# Document likelihood is %f -3279.462492803059
# Document likelihood is %f -3279.4580915490824
# Document likelihood is %f -3279.4575698354784
# Document likelihood is %f -3279.457454850671
# Document likelihood is %f -3279.457417078499
# Document likelihood is %f -3279.45740169492
# Document likelihood is %f -3279.457394840459
# Document likelihood is %f -3279.45739168032
# Document likelihood is %f -3279.457390204363
# Document likelihood is %f -3279.457389511482
# Document likelihood is %f -3279.4573891855325
# Document likelihood is %f -3279.4573890320617
# Document likelihood is %f -3279.457388959774
# Document likelihood is %f -3279.457388925719
# Document likelihood is %f -3279.4573889096746
# Document likelihood is %f -3279.4573889021153
# Document likelihood is %f -3279.4573888985537
# Document likelihood is %f -3279.4573888968757
# Document likelihood is %f -3279.457388896085
# Document likelihood is %f -3279.457388895712
# Document likelihood is %f -3279.4573888955365
# Document likelihood is %f -3279.4573888954537
# Document likelihood is %f -3279.4573888954155
# Document likelihood is %f -3279.4573888953964
# Document likelihood is %f -2621.8337008099384
# Document likelihood is %f -2545.6190129271845
# Document likelihood is %f -2545.6178901727662
# Document likelihood is %f -2545.6176756066925
# Document likelihood is %f -2545.617606102497
# Document likelihood is %f -2545.6175806858555
# Document likelihood is %f -2545.6175709808094
# Document likelihood is %f -2545.6175672143986
# Document likelihood is %f -2545.6175657436506
# Document likelihood is %f -2545.6175651679787
# Document likelihood is %f -2545.6175649424476
# Document likelihood is %f -2545.6175648540593
# Document likelihood is %f -2545.6175648194153
# Document likelihood is %f -2545.617564805835
# Document likelihood is %f -2545.617564800512
# Document likelihood is %f -2545.617564798425
# Document likelihood is %f -2545.6175647976074
# Document likelihood is %f -2545.617564797287
# Document likelihood is %f -2545.6175647971613
# Document likelihood is %f -2545.6175647971118
# Document likelihood is %f -2545.6175647970927
# Document likelihood is %f -2545.617564797085
# Document likelihood is %f -2545.617564797082
# Document likelihood is %f -2545.617564797081
# Document likelihood is %f -2545.6175647970804
# Document likelihood is %f -1846.2852900480934
# Document likelihood is %f -1815.9774032581354
# Document likelihood is %f -1815.9760186831886
# Document likelihood is %f -1815.9756757703078
# Document likelihood is %f -1815.9755402747232
# Document likelihood is %f -1815.975476358074
# Document likelihood is %f -1815.9754428643253
# Document likelihood is %f -1815.9754239087547
# Document likelihood is %f -1815.9754124775689
# Document likelihood is %f -1815.9754051988027
# Document likelihood is %f -1815.9754003469088
# Document likelihood is %f -1815.9753969904223
# Document likelihood is %f -1815.9753946004093
# Document likelihood is %f -1815.9753928612408
# Document likelihood is %f -1815.97539157539
# Document likelihood is %f -1815.9753906137316
# Document likelihood is %f -1815.9753898886067
# Document likelihood is %f -1815.9753893386305
# Document likelihood is %f -1815.9753889197518
# Document likelihood is %f -1815.9753885997652
# Document likelihood is %f -1815.9753883547946
# Document likelihood is %f -1815.97538816696
# Document likelihood is %f -1815.9753880227704
# Document likelihood is %f -1815.9753879119912
# Document likelihood is %f -1815.9753878268275
# Document likelihood is %f -3283.6996081621273
# Document likelihood is %f -3203.68222575021
# Document likelihood is %f -3203.6810785757143
# Document likelihood is %f -3203.6810494283372
# Document likelihood is %f -3203.681048333413
# Document likelihood is %f -3203.6810482870615
# Document likelihood is %f -3203.681048285027
# Document likelihood is %f -3203.681048284937
# Document likelihood is %f -3203.681048284933
# Document likelihood is %f -3203.6810482849323
# Document likelihood is %f -3203.681048284933
# Document likelihood is %f -3203.6810482849323
# Document likelihood is %f -3203.6810482849323
# Document likelihood is %f -3203.6810482849323
# Document likelihood is %f -3203.6810482849323
# Document likelihood is %f -3203.6810482849323
# Document likelihood is %f -3203.6810482849323
# Document likelihood is %f -3203.6810482849323
# Document likelihood is %f -3203.6810482849323
# Document likelihood is %f -3203.6810482849323
# Document likelihood is %f -3203.6810482849323
# Document likelihood is %f -3203.6810482849323
# Document likelihood is %f -3203.6810482849323
# Document likelihood is %f -3203.6810482849323
# Document likelihood is %f -3203.6810482849323
# Document likelihood is %f -1908.085038604116
# Document likelihood is %f -1845.6695193211146
# Document likelihood is %f -1845.6680584061444
# Document likelihood is %f -1845.6677059686365
# Document likelihood is %f -1845.66758589138
# Document likelihood is %f -1845.667536854095
# Document likelihood is %f -1845.6675140668465
# Document likelihood is %f -1845.6675024728786
# Document likelihood is %f -1845.667496223059
# Document likelihood is %f -1845.6674927378808
# Document likelihood is %f -1845.6674907573345
# Document likelihood is %f -1845.6674896202428
# Document likelihood is %f -1845.6674889638034
# Document likelihood is %f -1845.6674885837244
# Document likelihood is %f -1845.6674883633098
# Document likelihood is %f -1845.667488235378
# Document likelihood is %f -1845.6674881610898
# Document likelihood is %f -1845.667488117941
# Document likelihood is %f -1845.6674880928754
# Document likelihood is %f -1845.6674880783135
# Document likelihood is %f -1845.6674880698529
# Document likelihood is %f -1845.6674880649375
# Document likelihood is %f -1845.6674880620817
# Document likelihood is %f -1845.6674880604223
# Document likelihood is %f -1845.6674880594583
# Document likelihood is %f -4321.8525734276645
# Document likelihood is %f -4206.317968254612
# Document likelihood is %f -4206.314119911323
# Document likelihood is %f -4206.31338007317
# Document likelihood is %f -4206.313133622346
# Document likelihood is %f -4206.313033421955
# Document likelihood is %f -4206.312986904642
# Document likelihood is %f -4206.312963185064
# Document likelihood is %f -4206.3129503273685
# Document likelihood is %f -4206.312943095964
# Document likelihood is %f -4206.3129389420665
# Document likelihood is %f -4206.312936527599
# Document likelihood is %f -4206.312935114944
# Document likelihood is %f -4206.312934285407
# Document likelihood is %f -4206.312933797291
# Document likelihood is %f -4206.312933509744
# Document likelihood is %f -4206.312933340236
# Document likelihood is %f -4206.312933240275
# Document likelihood is %f -4206.312933181313
# Document likelihood is %f -4206.312933146532
# Document likelihood is %f -4206.31293312601
# Document likelihood is %f -4206.312933113903
# Document likelihood is %f -4206.312933106759
# Document likelihood is %f -4206.312933102544
# Document likelihood is %f -4206.312933100057
# Document likelihood is %f -2476.1169312017873
# Document likelihood is %f -2391.673348626446
# Document likelihood is %f -2391.6699402678846
# Document likelihood is %f -2391.669324236402
# Document likelihood is %f -2391.6691335297155
# Document likelihood is %f -2391.6690605426033
# Document likelihood is %f -2391.6690292135645
# Document likelihood is %f -2391.6690148579637
# Document likelihood is %f -2391.6690080060125
# Document likelihood is %f -2391.6690046414624
# Document likelihood is %f -2391.6690029535775
# Document likelihood is %f -2391.669002092256
# Document likelihood is %f -2391.6690016465022
# Document likelihood is %f -2391.6690014130495
# Document likelihood is %f -2391.6690012895115
# Document likelihood is %f -2391.6690012235313
# Document likelihood is %f -2391.6690011879955
# Document likelihood is %f -2391.6690011687065
# Document likelihood is %f -2391.669001158159
# Document likelihood is %f -2391.6690011523506
# Document likelihood is %f -2391.6690011491305
# Document likelihood is %f -2391.669001147334
# Document likelihood is %f -2391.669001146325
# Document likelihood is %f -2391.669001145756
# Document likelihood is %f -2391.669001145432
# Document likelihood is %f -3069.0008043076996
# Document likelihood is %f -3010.025202224824
# Document likelihood is %f -3010.0230144134603
# Document likelihood is %f -3010.022712672233
# Document likelihood is %f -3010.022646905344
# Document likelihood is %f -3010.0226293672254
# Document likelihood is %f -3010.0226242924637
# Document likelihood is %f -3010.0226227795965
# Document likelihood is %f -3010.022622323664
# Document likelihood is %f -3010.022622185672
# Document likelihood is %f -3010.022622143827
# Document likelihood is %f -3010.022622131124
# Document likelihood is %f -3010.022622127265
# Document likelihood is %f -3010.0226221260923
# Document likelihood is %f -3010.0226221257353
# Document likelihood is %f -3010.022622125627
# Document likelihood is %f -3010.0226221255944
# Document likelihood is %f -3010.022622125584
# Document likelihood is %f -3010.0226221255807
# Document likelihood is %f -3010.02262212558
# Document likelihood is %f -3010.02262212558
# Document likelihood is %f -3010.02262212558
# Document likelihood is %f -3010.02262212558
# Document likelihood is %f -3010.02262212558
# Document likelihood is %f -3010.0226221255793
# Document likelihood is %f -1543.0379095916587
# Document likelihood is %f -1502.9822692824837
# Document likelihood is %f -1502.9820360707517
# Document likelihood is %f -1502.9819905301576
# Document likelihood is %f -1502.981977073036
# Document likelihood is %f -1502.981972308804
# Document likelihood is %f -1502.9819704513309
# Document likelihood is %f -1502.9819696845361
# Document likelihood is %f -1502.9819693564773
# Document likelihood is %f -1502.98196921286
# Document likelihood is %f -1502.981969149034
# Document likelihood is %f -1502.981969120385
# Document likelihood is %f -1502.9819691074397
# Document likelihood is %f -1502.9819691015641
# Document likelihood is %f -1502.9819690988893
# Document likelihood is %f -1502.9819690976692
# Document likelihood is %f -1502.981969097112
# Document likelihood is %f -1502.981969096857
# Document likelihood is %f -1502.9819690967406
# Document likelihood is %f -1502.9819690966872
# Document likelihood is %f -1502.9819690966629
# Document likelihood is %f -1502.9819690966517
# Document likelihood is %f -1502.9819690966465
# Document likelihood is %f -1502.9819690966442
# Document likelihood is %f -1502.981969096643
# Document likelihood is %f -1958.1294368743165
# Document likelihood is %f -1890.0177724557834
# Document likelihood is %f -1890.0152221992525
# Document likelihood is %f -1890.0148579034094
# Document likelihood is %f -1890.0147862916065
# Document likelihood is %f -1890.0147706113414
# Document likelihood is %f -1890.0147669937528
# Document likelihood is %f -1890.0147661325373
# Document likelihood is %f -1890.0147659231761
# Document likelihood is %f -1890.01476587152
# Document likelihood is %f -1890.0147658586347
# Document likelihood is %f -1890.0147658553935
# Document likelihood is %f -1890.014765854573
# Document likelihood is %f -1890.014765854364
# Document likelihood is %f -1890.0147658543108
# Document likelihood is %f -1890.014765854297
# Document likelihood is %f -1890.0147658542935
# Document likelihood is %f -1890.0147658542926
# Document likelihood is %f -1890.0147658542924
# Document likelihood is %f -1890.0147658542924
# Document likelihood is %f -1890.0147658542921
# Document likelihood is %f -1890.0147658542924
# Document likelihood is %f -1890.0147658542924
# Document likelihood is %f -1890.0147658542924
# Document likelihood is %f -1890.0147658542924
# Document likelihood is %f -1192.2739674560426
# Document likelihood is %f -1162.100927055556
# Document likelihood is %f -1162.1008613746935
# Document likelihood is %f -1162.100849688953
# Document likelihood is %f -1162.1008470690417
# Document likelihood is %f -1162.1008464249414
# Document likelihood is %f -1162.1008462594245
# Document likelihood is %f -1162.1008462159411
# Document likelihood is %f -1162.1008462043885
# Document likelihood is %f -1162.1008462013012
# Document likelihood is %f -1162.1008462004738
# Document likelihood is %f -1162.1008462002517
# Document likelihood is %f -1162.100846200192
# Document likelihood is %f -1162.1008462001762
# Document likelihood is %f -1162.1008462001719
# Document likelihood is %f -1162.1008462001705
# Document likelihood is %f -1162.1008462001705
# Document likelihood is %f -1162.1008462001703
# Document likelihood is %f -1162.10084620017
# Document likelihood is %f -1162.1008462001703
# Document likelihood is %f -1162.1008462001703
# Document likelihood is %f -1162.10084620017
# Document likelihood is %f -1162.1008462001703
# Document likelihood is %f -1162.1008462001703
# Document likelihood is %f -1162.1008462001703
# Document likelihood is %f -713.7889271384377
# Document likelihood is %f -693.3757687089562
# Document likelihood is %f -693.3757687004972
# Document likelihood is %f -693.3757687004972
# Document likelihood is %f -693.3757687004972
# Document likelihood is %f -693.3757687004972
# Document likelihood is %f -693.3757687004972
# Document likelihood is %f -693.3757687004972
# Document likelihood is %f -693.3757687004972
# Document likelihood is %f -693.3757687004972
# Document likelihood is %f -693.3757687004972
# Document likelihood is %f -693.3757687004972
# Document likelihood is %f -693.3757687004972
# Document likelihood is %f -693.3757687004972
# Document likelihood is %f -693.3757687004972
# Document likelihood is %f -693.3757687004972
# Document likelihood is %f -693.3757687004972
# Document likelihood is %f -693.3757687004972
# Document likelihood is %f -693.3757687004972
# Document likelihood is %f -693.3757687004972
# Document likelihood is %f -693.3757687004972
# Document likelihood is %f -693.3757687004972
# Document likelihood is %f -693.3757687004972
# Document likelihood is %f -693.3757687004972
# Document likelihood is %f -693.3757687004972
# Document likelihood is %f -1345.2005415172773
# Document likelihood is %f -1304.3044148826723
# Document likelihood is %f -1304.3032671371498
# Document likelihood is %f -1304.303047938862
# Document likelihood is %f -1304.3029780540185
# Document likelihood is %f -1304.3029497262155
# Document likelihood is %f -1304.3029371267912
# Document likelihood is %f -1304.3029313313846
# Document likelihood is %f -1304.3029286310916
# Document likelihood is %f -1304.3029273661955
# Document likelihood is %f -1304.3029267722925
# Document likelihood is %f -1304.3029264931424
# Document likelihood is %f -1304.30292636187
# Document likelihood is %f -1304.302926300124
# Document likelihood is %f -1304.3029262710777
# Document likelihood is %f -1304.3029262574132
# Document likelihood is %f -1304.302926250985
# Document likelihood is %f -1304.3029262479606
# Document likelihood is %f -1304.3029262465375
# Document likelihood is %f -1304.3029262458683
# Document likelihood is %f -1304.3029262455534
# Document likelihood is %f -1304.3029262454054
# Document likelihood is %f -1304.3029262453354
# Document likelihood is %f -1304.3029262453028
# Document likelihood is %f -1304.3029262452874
# Document likelihood is %f -396.92391751339994
# Document likelihood is %f -380.01450522802793
# Document likelihood is %f -380.014505228028
# Document likelihood is %f -380.014505228028
# Document likelihood is %f -380.014505228028
# ...
# Document likelihood is %f -2301.275079954601
# Document likelihood is %f -2301.275079951584
# Document likelihood is %f -1512.370094556379
# Document likelihood is %f -1477.709789959349
# Document likelihood is %f -1477.7088776829692
# Document likelihood is %f -1477.7087806658162
# Document likelihood is %f -1477.7087666648479
# Document likelihood is %f -1477.7087644823769
# Document likelihood is %f -1477.7087641365088
# Document likelihood is %f -1477.7087640815048
# Document likelihood is %f -1477.7087640727505
# Document likelihood is %f -1477.7087640713569
# Document likelihood is %f -1477.708764071135
# Document likelihood is %f -1477.7087640710997
# Document likelihood is %f -1477.708764071094
# Document likelihood is %f -1477.7087640710931
# Document likelihood is %f -1477.708764071093
# Document likelihood is %f -1477.708764071093
# Document likelihood is %f -1477.7087640710931
# Document likelihood is %f -1477.708764071093
# Document likelihood is %f -1477.708764071093
# Document likelihood is %f -1477.708764071093
# Document likelihood is %f -1477.7087640710931
# Document likelihood is %f -1477.708764071093
# Document likelihood is %f -1477.708764071093
# Document likelihood is %f -1477.708764071093
# Document likelihood is %f -1477.708764071093
# Document likelihood is %f -775.440433543558
# Document likelihood is %f -742.2907003325713
# Document likelihood is %f -742.290693287212
# Document likelihood is %f -742.2906932247595
# Document likelihood is %f -742.2906932242256
# Document likelihood is %f -742.2906932242211
# Document likelihood is %f -742.2906932242211
# Document likelihood is %f -742.2906932242211
# Document likelihood is %f -742.2906932242211
# Document likelihood is %f -742.2906932242211
# Document likelihood is %f -742.2906932242211
# Document likelihood is %f -742.2906932242211
# Document likelihood is %f -742.2906932242211
# Document likelihood is %f -742.2906932242211
# Document likelihood is %f -742.2906932242211
# Document likelihood is %f -742.2906932242211
# Document likelihood is %f -742.2906932242211
# Document likelihood is %f -742.2906932242211
# Document likelihood is %f -742.2906932242211
# Document likelihood is %f -742.2906932242211
# Document likelihood is %f -742.2906932242211
# Document likelihood is %f -742.2906932242211
# Document likelihood is %f -742.2906932242211
# Document likelihood is %f -742.2906932242211
# Document likelihood is %f -742.2906932242211
# Document likelihood is %f -1466.4271751445262
# Document likelihood is %f -1428.5086649317263
# Document likelihood is %f -1428.5082092334317
# Document likelihood is %f -1428.5081832138223
# Document likelihood is %f -1428.5081810973363
# Document likelihood is %f -1428.5081808511773
# Document likelihood is %f -1428.5081808157363
# Document likelihood is %f -1428.5081808101854
# Document likelihood is %f -1428.5081808092914
# Document likelihood is %f -1428.5081808091463
# Document likelihood is %f -1428.5081808091227
# Document likelihood is %f -1428.5081808091188
# Document likelihood is %f -1428.5081808091181
# Document likelihood is %f -1428.508180809118
# Document likelihood is %f -1428.5081808091181
# Document likelihood is %f -1428.5081808091181
# Document likelihood is %f -1428.5081808091181
# Document likelihood is %f -1428.5081808091181
# Document likelihood is %f -1428.5081808091181
# Document likelihood is %f -1428.5081808091181
# Document likelihood is %f -1428.508180809118
# Document likelihood is %f -1428.5081808091181
# Document likelihood is %f -1428.5081808091181
# Document likelihood is %f -1428.5081808091181
# Document likelihood is %f -1428.5081808091181
# Document likelihood is %f -2500.6460781731585
# Document likelihood is %f -2447.48375961648
# Document likelihood is %f -2447.4797353581525
# Document likelihood is %f -2447.478858276194
# Document likelihood is %f -2447.4785539809163
# Document likelihood is %f -2447.4784220853016
# Document likelihood is %f -2447.4783565874577
# Document likelihood is %f -2447.478320848992
# Document likelihood is %f -2447.478299889861
# Document likelihood is %f -2447.478286858793
# Document likelihood is %f -2447.4782783535475
# Document likelihood is %f -2447.478272569388
# Document likelihood is %f -2447.478268494491
# Document likelihood is %f -2447.478265534247
# Document likelihood is %f -2447.478263324953
# Document likelihood is %f -2447.478261636408
# Document likelihood is %f -2447.478260318543
# Document likelihood is %f -2447.4782592709457
# Document likelihood is %f -2447.4782584248283
# Document likelihood is %f -2447.4782577320284
# Document likelihood is %f -2447.4782571581172
# Document likelihood is %f -2447.478256677994
# Document likelihood is %f -2447.4782562730043
# Document likelihood is %f -2447.4782559290315
# Document likelihood is %f -2447.478255635207
# Document likelihood is %f -2454.7134385296486
# Document likelihood is %f -2371.6008365609005
# Document likelihood is %f -2371.5970118774776
# Document likelihood is %f -2371.5963638729145
# Document likelihood is %f -2371.5961674789673
# Document likelihood is %f -2371.5960888292966
# Document likelihood is %f -2371.59605253372
# Document likelihood is %f -2371.5960344199757
# Document likelihood is %f -2371.5960249341497
# Document likelihood is %f -2371.596019800295
# Document likelihood is %f -2371.5960169536256
# Document likelihood is %f -2371.5960153457245
# Document likelihood is %f -2371.596014424481
# Document likelihood is %f -2371.59601389083
# Document likelihood is %f -2371.596013579092
# Document likelihood is %f -2371.5960133958197
# Document likelihood is %f -2371.5960132875516
# Document likelihood is %f -2371.59601322336
# Document likelihood is %f -2371.596013185197
# Document likelihood is %f -2371.5960131624634
# Document likelihood is %f -2371.596013148899
# Document likelihood is %f -2371.596013140798
# Document likelihood is %f -2371.5960131359548
# Document likelihood is %f -2371.5960131330576
# Document likelihood is %f -2371.596013131324
# Document likelihood is %f -1356.3876320161303
# Document likelihood is %f -1323.082883917274
# Document likelihood is %f -1323.0817954183294
# Document likelihood is %f -1323.0816373721152
# Document likelihood is %f -1323.0816040689422
# Document likelihood is %f -1323.081596147726
# Document likelihood is %f -1323.081594204032
# Document likelihood is %f -1323.081593723554
# Document likelihood is %f -1323.081593604576
# Document likelihood is %f -1323.0815935751025
# Document likelihood is %f -1323.0815935678004
# Document likelihood is %f -1323.0815935659916
# Document likelihood is %f -1323.0815935655432
# Document likelihood is %f -1323.0815935654323
# Document likelihood is %f -1323.0815935654045
# Document likelihood is %f -1323.081593565398
# Document likelihood is %f -1323.0815935653961
# Document likelihood is %f -1323.0815935653957
# Document likelihood is %f -1323.0815935653955
# Document likelihood is %f -1323.0815935653955
# Document likelihood is %f -1323.0815935653955
# Document likelihood is %f -1323.0815935653955
# Document likelihood is %f -1323.0815935653955
# Document likelihood is %f -1323.0815935653955
# Document likelihood is %f -1323.0815935653955
# Document likelihood is %f -1549.5730513312433
# Document likelihood is %f -1509.2208431446868
# Document likelihood is %f -1509.2205011929398
# Document likelihood is %f -1509.220493679016
# Document likelihood is %f -1509.2204934817319
# Document likelihood is %f -1509.2204934763276
# Document likelihood is %f -1509.220493476178
# Document likelihood is %f -1509.220493476174
# Document likelihood is %f -1509.220493476174
# Document likelihood is %f -1509.220493476174
# Document likelihood is %f -1509.220493476174
# Document likelihood is %f -1509.220493476174
# Document likelihood is %f -1509.220493476174
# Document likelihood is %f -1509.220493476174
# Document likelihood is %f -1509.220493476174
# Document likelihood is %f -1509.220493476174
# Document likelihood is %f -1509.220493476174
# Document likelihood is %f -1509.220493476174
# Document likelihood is %f -1509.220493476174
# Document likelihood is %f -1509.220493476174
# Document likelihood is %f -1509.220493476174
# Document likelihood is %f -1509.220493476174
# Document likelihood is %f -1509.220493476174
# Document likelihood is %f -1509.220493476174
# Document likelihood is %f -1509.220493476174
# Document likelihood is %f -1404.768984094256
# Document likelihood is %f -1369.9749227922757
# Document likelihood is %f -1369.9744135302958
# Document likelihood is %f -1369.9743719269527
# Document likelihood is %f -1369.9743683213726
# Document likelihood is %f -1369.9743680068048
# Document likelihood is %f -1369.9743679793166
# Document likelihood is %f -1369.974367976913
# Document likelihood is %f -1369.974367976703
# Document likelihood is %f -1369.9743679766843
# Document likelihood is %f -1369.974367976683
# Document likelihood is %f -1369.9743679766827
# Document likelihood is %f -1369.9743679766827
# Document likelihood is %f -1369.9743679766827
# Document likelihood is %f -1369.974367976683
# Document likelihood is %f -1369.9743679766827
# Document likelihood is %f -1369.974367976683
# Document likelihood is %f -1369.974367976683
# Document likelihood is %f -1369.9743679766825
# Document likelihood is %f -1369.9743679766825
# Document likelihood is %f -1369.9743679766825
# Document likelihood is %f -1369.9743679766825
# Document likelihood is %f -1369.9743679766825
# Document likelihood is %f -1369.9743679766825
# Document likelihood is %f -1369.9743679766825
# Document likelihood is %f -655.9561796383548
# Document likelihood is %f -634.7055247096905
# Document likelihood is %f -634.7055247003425
# Document likelihood is %f -634.7055247003425
# Document likelihood is %f -634.7055247003425
# Document likelihood is %f -634.7055247003425
# Document likelihood is %f -634.7055247003425
# Document likelihood is %f -634.7055247003425
# Document likelihood is %f -634.7055247003425
# Document likelihood is %f -634.7055247003425
# Document likelihood is %f -634.7055247003425
# Document likelihood is %f -634.7055247003425
# Document likelihood is %f -634.7055247003425
# Document likelihood is %f -634.7055247003425
# Document likelihood is %f -634.7055247003425
# Document likelihood is %f -634.7055247003425
# Document likelihood is %f -634.7055247003425
# Document likelihood is %f -634.7055247003425
# Document likelihood is %f -634.7055247003425
# Document likelihood is %f -634.7055247003425
# Document likelihood is %f -634.7055247003425
# Document likelihood is %f -634.7055247003425
# Document likelihood is %f -634.7055247003425
# Document likelihood is %f -634.7055247003425
# Document likelihood is %f -634.7055247003425
# Document likelihood is %f -1574.8893202158401
# Document likelihood is %f -1540.9492460808638
# Document likelihood is %f -1540.9486903745888
# Document likelihood is %f -1540.9485803872522
# Document likelihood is %f -1540.9485346370263
# Document likelihood is %f -1540.9485106882018
# Document likelihood is %f -1540.9484964639332
# Document likelihood is %f -1540.948487266149
# Document likelihood is %f -1540.9484809422188
# Document likelihood is %f -1540.9484763880273
# Document likelihood is %f -1540.9484729876156
# Document likelihood is %f -1540.9484703741964
# Document likelihood is %f -1540.9484683176615
# Document likelihood is %f -1540.9484666673516
# Document likelihood is %f -1540.9484653210466
# Document likelihood is %f -1540.9484642072666
# Document likelihood is %f -1540.9484632747158
# Document likelihood is %f -1540.9484624857455
# Document likelihood is %f -1540.9484618121742
# Document likelihood is %f -1540.9484612325364
# Document likelihood is %f -1540.9484607302263
# Document likelihood is %f -1540.9484602922194
# Document likelihood is %f -1540.9484599081704
# Document likelihood is %f -1540.948459569769
# Document likelihood is %f -1540.9484592702715
# Document likelihood is %f -1239.8535497988485
# Document likelihood is %f -1210.162647674566
# Document likelihood is %f -1210.161388318622
# Document likelihood is %f -1210.1610734032988
# Document likelihood is %f -1210.1609544360438
# Document likelihood is %f -1210.1608951277876
# Document likelihood is %f -1210.1608601980574
# Document likelihood is %f -1210.1608375867736
# Document likelihood is %f -1210.1608220905214
# Document likelihood is %f -1210.160811060982
# Document likelihood is %f -1210.1608029965214
# Document likelihood is %f -1210.160796981264
# Document likelihood is %f -1210.160792426137
# Document likelihood is %f -1210.160788936374
# Document likelihood is %f -1210.1607862385765
# Document likelihood is %f -1210.1607841382688
# Document likelihood is %f -1210.1607824940527
# Document likelihood is %f -1210.1607812012633
# Document likelihood is %f -1210.1607801812802
# Document likelihood is %f -1210.1607793743353
# Document likelihood is %f -1210.160778734548
# Document likelihood is %f -1210.1607782264173
# Document likelihood is %f -1210.1607778222972
# Document likelihood is %f -1210.160777500546
# Document likelihood is %f -1210.1607772441519
# Document likelihood is %f -3499.989222146868
# Document likelihood is %f -3425.475072882793
# Document likelihood is %f -3425.4730785704332
# Document likelihood is %f -3425.472796695333
# Document likelihood is %f -3425.4727294926874
# Document likelihood is %f -3425.472711016679
# Document likelihood is %f -3425.4727055037374
# Document likelihood is %f -3425.472703736598
# Document likelihood is %f -3425.4727031311268
# Document likelihood is %f -3425.4727029112646
# Document likelihood is %f -3425.4727028276393
# Document likelihood is %f -3425.4727027947283
# Document likelihood is %f -3425.472702781468
# Document likelihood is %f -3425.4727027760414
# Document likelihood is %f -3425.472702773798
# Document likelihood is %f -3425.472702772865
# Document likelihood is %f -3425.4727027724753
# Document likelihood is %f -3425.4727027723125
# Document likelihood is %f -3425.472702772244
# Document likelihood is %f -3425.4727027722156
# Document likelihood is %f -3425.472702772203
# Document likelihood is %f -3425.4727027721983
# Document likelihood is %f -3425.472702772196
# Document likelihood is %f -3425.4727027721956
# Document likelihood is %f -3425.4727027721947
# Document likelihood is %f -1608.758346430779
# Document likelihood is %f -1579.865285648038
# Document likelihood is %f -1579.8651695233723
# Document likelihood is %f -1579.8651683210237
# Document likelihood is %f -1579.8651683083835
# Document likelihood is %f -1579.8651683082505
# Document likelihood is %f -1579.8651683082492
# Document likelihood is %f -1579.8651683082492
# Document likelihood is %f -1579.8651683082492
# Document likelihood is %f -1579.865168308249
# Document likelihood is %f -1579.865168308249
# Document likelihood is %f -1579.865168308249
# Document likelihood is %f -1579.865168308249
# Document likelihood is %f -1579.865168308249
# Document likelihood is %f -1579.865168308249
# Document likelihood is %f -1579.865168308249
# Document likelihood is %f -1579.865168308249
# Document likelihood is %f -1579.865168308249
# Document likelihood is %f -1579.865168308249
# Document likelihood is %f -1579.865168308249
# Document likelihood is %f -1579.865168308249
# Document likelihood is %f -1579.865168308249
# Document likelihood is %f -1579.865168308249
# Document likelihood is %f -1579.865168308249
# Document likelihood is %f -1579.865168308249
# Document likelihood is %f -6650.314104314674
# Document likelihood is %f -6466.521740655583
# Document likelihood is %f -6466.508921136701
# Document likelihood is %f -6466.507503756721
# Document likelihood is %f -6466.5071575104075
# Document likelihood is %f -6466.507033396689
# Document likelihood is %f -6466.506978799667
# Document likelihood is %f -6466.506951695252
# Document likelihood is %f -6466.5069371742575
# Document likelihood is %f -6466.50692900471
# Document likelihood is %f -6466.506924261434
# Document likelihood is %f -6466.506921450755
# Document likelihood is %f -6466.506919762853
# Document likelihood is %f -6466.506918740117
# Document likelihood is %f -6466.506918116608
# Document likelihood is %f -6466.506917734842
# Document likelihood is %f -6466.506917500356
# Document likelihood is %f -6466.506917355991
# Document likelihood is %f -6466.50691726695
# Document likelihood is %f -6466.506917211952
# Document likelihood is %f -6466.506917177941
# Document likelihood is %f -6466.5069171568875
# Document likelihood is %f -6466.506917143843
# Document likelihood is %f -6466.506917135756
# Document likelihood is %f -6466.506917130739

# %%
print("The topics words are:")
aux[2][-15:]
aux2 =[]
print("The background words are:")
background_vector = topic_vec(background_words,vocabulary)

background_vector[-15:]
# Out:
# The topics words are:
# array([['moción', '0.007874666682046833'],
#        ['hitler', '0.007874666682046833'],
#        ['rutina', '0.007874666682046833'],
#        ['palacio', '0.007874666682046833'],
#        ['gobierno', '0.008236101578586072'],
#        ['día', '0.00917477492026317'],
#        ['momento', '0.01056043556750079'],
#        ['julio', '0.011454410178621833'],
#        ['alemán', '0.011722602561958149'],
#        ['roma', '0.0117673012925142'],
#        ['scalfaro', '0.01181200002307025'],
#        ['duce', '0.015749333364093666'],
#        ['italiano', '0.015749333364093666'],
#        ['italia', '0.01968666670511708'],
#        ['mussolini', '0.0236240000461405']], dtype='<U34')

# %%
serializeObject(aux, "espectation_max_all.pkl")
